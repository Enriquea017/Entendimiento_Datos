# %% [markdown]
# <a href="https://colab.research.google.com/github/Enriquea017/Entendimiento_Datos/blob/main/C%C3%B3digo_entendimiento_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Carga de librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga de la base
Hawaii = pd.read_csv("listings.csv")
Hawaii
# Out:
#             id                            listing_url       scrape_id  \
# 0         5269      https://www.airbnb.com/rooms/5269  20250306035046
# 1         5387      https://www.airbnb.com/rooms/5387  20250306035046
# 2         5480      https://www.airbnb.com/rooms/5480  20250306035046
# 3         5532      https://www.airbnb.com/rooms/5532  20250306035046
# 4         7888      https://www.airbnb.com/rooms/7888  20250306035046
# ...        ...                                    ...             ...
# 6516  29061693  https://www.airbnb.com/rooms/29061693  20250306035046
# 6517  29080356  https://www.airbnb.com/rooms/29080356  20250306035046
# 6518  29082568  https://www.airbnb.com/rooms/29082568  20250306035046
# 6519  29095678  https://www.airbnb.com/rooms/29095678  20250306035046
# 6520  29098648  https://www.airbnb.com/rooms/29098648  20250306035046
#
#      last_scraped           source  \
# 0      2025-03-14      city scrape
# 1      2025-03-15      city scrape
# ...

# %%
Hawaii.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
selec.shape
# Out:
# (6521, 50)

# %%
#Selección de las columnas de interés
selec = Hawaii[['id', 'name', 'host_id', 'host_since', 'description',
       'host_response_time', 'host_response_rate', 'host_acceptance_rate',
       'host_is_superhost',
       'host_neighbourhood',
       'host_total_listings_count', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified',
       'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'property_type', 'room_type', 'accommodates', 'bathrooms',
       'bedrooms', 'beds', 'amenities', 'price',
       'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm',
       'availability_30', 'availability_60', 'availability_90',
       'availability_365', 'number_of_reviews',
       'number_of_reviews_ly', 'estimated_occupancy_l365d',
       'estimated_revenue_l365d',
       'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 'instant_bookable',
       'reviews_per_month', 'license']]

# %%
Hawaii_50 = Hawaii.rename(columns={
    'id': 'ID',
    'name': 'nombre',
    'host_id': 'ID_host',
    'host_since': 'host_desde',
    'description': 'descripción',
    'host_response_time': 'tiempo_respuesta',
    'host_response_rate': 'tasa_respuesta',
    'host_acceptance_rate': 'tasa_aceptación_host',
    'host_is_superhost': 'superhost',
    'host_neighbourhood': 'host_vecindario',
    'host_total_listings_count': 'host_listados',
    'host_verifications': 'host_contacto',
    'host_has_profile_pic': 'host_foto_perfil',
    'host_identity_verified': 'host_identidad_verif',
    'neighbourhood_cleansed': 'vecindario',
    'neighbourhood_group_cleansed': 'grupo_vecindario',
    'property_type': 'tipo_propiedad',
    'room_type': 'tipo_habitación',
    'accommodates': 'alojados',
    'bathrooms': 'baños',
    'bedrooms': 'recámaras',
    'beds': 'camas',
    'amenities': 'amenidades',
    'price': 'precio',
    'minimum_nights': 'min_noches',
    'maximum_nights': 'max_noches',
    'minimum_minimum_nights': 'min_min_noches',
    'maximum_minimum_nights': 'max_min_noches',
    'minimum_maximum_nights': 'min_max_noches',
    'maximum_maximum_nights': 'max_max_noches',
    'minimum_nights_avg_ntm': 'prom_min_noches',
    'maximum_nights_avg_ntm': 'prom_max_noches',
    'availability_30': 'disponibilidad_30',
    'availability_60': 'disponibilidad_60',
    'availability_90': 'disponibilidad_90',
    'availability_365': 'disponibilidad_365',
    'number_of_reviews': 'num_reviews',
    'number_of_reviews_ly': 'ly_reviews',
    'estimated_occupancy_l365d': 'ocupación_estimada_365',
    'estimated_revenue_l365d': 'ganancia_estimada_365',
    'review_scores_rating': 'calificación_general',
    'review_scores_accuracy': 'cal_precisión',
    'review_scores_cleanliness': 'cal_limpieza',
    'review_scores_checkin': 'cal_check-in',
    'review_scores_communication': 'cal_comunicación',
    'review_scores_location': 'cal_ubicación',
    'review_scores_value': 'cal_valor',
    'instant_bookable': 'agendado_instante',
    'reviews_per_month': 'reviews_mes',
    'license': 'licencia'
})

# %%
#Descarga de la base
Hawaii_renamed.to_csv("Hawaii_50.csv", index=False)
